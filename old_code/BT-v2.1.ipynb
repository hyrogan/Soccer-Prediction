# %%
import numpy as np
import pandas as pd
import math
from scipy.stats import norm

# %%
# Function to initialize ratings
def initialize_ratings(df_results, df_fixtures):
    ratings = {}

    # Iterate over teams in the results data
    teams = set(df_results['home_team']).union(set(df_results['away_team'])).union(set(df_fixtures['home_team'])).union(set(df_fixtures['away_team']))
    for team in teams:
        # Initialize ratings for each team
        ratings[team] = {
            'brH': 0.0,
            'brA': 0.0,
            'continuous_overunderperformances': 0
        }
    print('Teams:', teams, end='\n\n')
    return ratings

# %%
# Function to update ratings based on results data
def update_ratings(df_results, ratings):

    #lambda: Determines to what extent the new match results influence the team ratings (could be improved to include temporal difference between matches)
    learning_rate_lambda = 0.054

    #psi: diminish the impact each additional goal difference error has on team ratings
    diminishing_function_psi = lambda error: 3 * np.log10(1 + error)

    #gamma: determines to what extent performances at the home grounds influence away team ratings and vice versa
    learning_rate_gamma = 0.79

    # Iterate over each match in the results data
    for index, row in df_results.iterrows():
        print("Game Nr:", index)

        if abs(ratings['Wigan Athletic']['brH']) > 1:
            print("Wigan Athletic has reached |brH| >1 at game:", index)

        if index == 2000:
            break

        home_team = row['home_team']
        away_team = row['away_team']
        #print("home_team:", home_team)
        #print("away_team:", away_team)

        if home_team == 'Wigan Athletic' or away_team == 'Wigan Athletic':
            continue


        observed_goal_difference = row['home_goals'] - row['away_goals']
        #print("observed_goal_difference:", observed_goal_difference)

        #Calculate expected goals for home team
        #expected_goal_x = round((10 ** (abs(ratings[home_team]['brH']) / 3)) - 1,5)
        expected_goal_x_temp = abs(ratings[home_team]['brH']) / 3
        expected_goal_x = np.power(10, expected_goal_x_temp) - 1
        #print("expected_goal_x:", expected_goal_x)

        # Calculate expected goals for away team
        #expected_goal_y = round((10 ** (abs(ratings[away_team]['brA']) / 3)) - 1,5)
        expected_goal_y_temp = abs(ratings[away_team]['brA']) / 3
        expected_goal_y = np.power(10, expected_goal_y_temp) - 1
        #print("expected_goal_y:", expected_goal_y)

        # Calculate expected goal difference based on ratings
        expected_goal_difference = expected_goal_x - expected_goal_y
        #print("expected_goal_difference:", expected_goal_difference)


        # Calculate the error between observed and expected goal difference
        error = abs(observed_goal_difference - expected_goal_difference)
        #print("error:", error)

        psi_temp = diminishing_function_psi(error)

        # Diminish the impact of the goal difference error for both teams x and y respectively
        if (expected_goal_difference < observed_goal_difference):
            diminishing_function_psi_x = psi_temp
            diminishing_function_psi_y = -psi_temp
        else:
            diminishing_function_psi_x = -psi_temp
            diminishing_function_psi_y = psi_temp
        #print("diminishing_function_psi_x:", diminishing_function_psi_x)
        #print("diminishing_function_psi_y:", diminishing_function_psi_y)

        # Update the home team ratings
        previous_home_rating_x = ratings[home_team]['brH']
        previous_away_rating_x = ratings[home_team]['brA']
        #print("previous_home_rating:", previous_home_rating_x)
        #print("previous_away_rating:", previous_away_rating_x)

        """
        temp_1 = previous_home_rating_x + diminishing_function_psi_x * learning_rate_lambda
        temp_2 = previous_away_rating_x + (ratings[home_team]['brH'] - previous_home_rating_x) * learning_rate_gamma
        """

        ratings[home_team]['brH'] = previous_home_rating_x + diminishing_function_psi_x * learning_rate_lambda
        ratings[home_team]['brA'] = previous_away_rating_x + (ratings[home_team]['brH'] - previous_home_rating_x) * learning_rate_gamma
        #print("ratings[home_team]['brH']:", ratings[home_team]['brH'])
        #print("ratings[home_team]['brA']:", ratings[home_team]['brA'])

        # Update the away team ratings
        previous_home_rating_y = ratings[away_team]['brH']
        previous_away_rating_y = ratings[away_team]['brA']
        #print("previous_home_rating:", previous_home_rating_y)
        #print("previous_away_rating:", previous_away_rating_y)

        ratings[away_team]['brA'] = previous_away_rating_y + diminishing_function_psi_y * learning_rate_lambda
        ratings[away_team]['brH'] = previous_home_rating_y + (ratings[away_team]['brA'] - previous_away_rating_y) * learning_rate_gamma
        #print("ratings[away_team]['brH']:", ratings[away_team]['brH'])
        #print("ratings[away_team]['brA']:", ratings[away_team]['brA'])

        #print("home team: previous overunderperformance:", ratings[home_team]['continuous_overunderperformances'])
        #print("away team: previous overunderperformance:", ratings[away_team]['continuous_overunderperformances'])

        # Update the continuous over/underperformances for the home team
        if (observed_goal_difference > expected_goal_difference):
            ratings[home_team]['continuous_overunderperformances'] = max(1, ratings[home_team]['continuous_overunderperformances'] + 1)
            ratings[away_team]['continuous_overunderperformances'] = min(-1, ratings[away_team]['continuous_overunderperformances'] - 1)
        elif (observed_goal_difference < expected_goal_difference):
            ratings[home_team]['continuous_overunderperformances'] = min(-1, ratings[home_team]['continuous_overunderperformances'] - 1)
            ratings[away_team]['continuous_overunderperformances'] = max(1, ratings[away_team]['continuous_overunderperformances'] + 1)

        #print("home team: updated overunderperformance:", ratings[home_team]['continuous_overunderperformances'])
        #print("away team: updated overunderperformance:", ratings[away_team]['continuous_overunderperformances'], end='\n\n')


        #What is supposed to happen in the rare case of observed goals = expected goals?

        """"
        #printing to check
        print("Home Team:", home_team)
        print("Away Team:", away_team)
        print("Observed Goal Difference:", observed_goal_difference)
        print("Expected Goal Difference:", expected_goal_difference)
        print("Error:", error)
        print("Background Rating x Home:", ratings[home_team]['brH'])
        print("Background Rating x Away:", ratings[home_team]['brA'])
        print("Background Rating y Home:", ratings[away_team]['brH'])
        print("Background Rating y Away:", ratings[away_team]['brA'])
        print("Continuous Over/Underperformances x:", ratings[home_team]['continuous_overunderperformances'])
        print("Continuous Over/Underperformances y:", ratings[away_team]['continuous_overunderperformances'])
        """


    return ratings

# %%
# Function to calculate the rating difference between two teams
def calculate_rating_difference(df_fixtures, ratings):

    rating_differences = []

     #phi: Represents the number of continuous performances, above or below expectations, which do not trigger the form factor
    form_threshold_phi = 1

    #mu: represents the rating difference used to establish provisional ratings from background ratings
    rating_impact_mu = 0.01

    #delta: the level by which rating impact μ diminishes with each additional continuous over/under-performance
    diminishing_factor_delta = 2.5

    # Iterate over each match in the results data
    for index, row in df_fixtures.iterrows():
        home_team = row['home_team']
        away_team = row['away_team']

        # Calculate performance factor for home team
        a = ratings[home_team]['continuous_overunderperformances'] - form_threshold_phi
        b = a ** diminishing_factor_delta
        if (a == 0):
            form_factor_home = 0
        else:
            form_factor_home = a / b

        # Calculate home team rating
        home_rating = ratings[home_team]['brH']
        if (ratings[home_team]['continuous_overunderperformances'] > form_threshold_phi):
            home_rating = ratings[home_team]['brH'] + rating_impact_mu * form_factor_home
        if (ratings[home_team]['continuous_overunderperformances'] < -form_threshold_phi):
            home_rating = ratings[home_team]['brH'] - rating_impact_mu * form_factor_home

        # Calculate performance factor for away team
        c = ratings[away_team]['continuous_overunderperformances'] - form_threshold_phi
        d = c ** diminishing_factor_delta
        if (c == 0):
            form_factor_away = 0
        else:
            form_factor_away = c / d

        # Calculate away team rating
        away_rating = ratings[away_team]['brA']
        if (ratings[away_team]['continuous_overunderperformances'] > form_threshold_phi):
            away_rating = ratings[away_team]['brA'] + rating_impact_mu * form_factor_away
        if (ratings[away_team]['continuous_overunderperformances'] < -form_threshold_phi):
            away_rating = ratings[away_team]['brA'] - rating_impact_mu * form_factor_away

        rating_difference = home_rating - away_rating

        rating_differences.append(rating_difference)

    print("Rating differences:", rating_differences, end='\n\n')


    return rating_differences

# %%
def calculate_probabilities(rating_difference):

    mean_rating_difference = 0.4  # Adjust this value based on your data
    standard_deviation = 2.0  # Adjust this value based on your data

    home_win_probability = norm.cdf(rating_difference, loc=mean_rating_difference, scale=standard_deviation)

    draw_probability = norm.cdf(0, loc=mean_rating_difference, scale=standard_deviation)

    away_win_probability = 1 - home_win_probability - draw_probability


    return home_win_probability, draw_probability, away_win_probability

# %%
def predict_outcomes(df_fixtures, ratings):
    for index, row in df_fixtures.iterrows():
        home_team = row['home_team']
        away_team = row['away_team']
        rating_difference = calculate_rating_difference(df_fixtures, ratings)

        home_win_prob, draw_prob, away_win_prob = calculate_probabilities(rating_difference)

        print(f"{home_team} - {away_team}: Outcome Predictions")
        print(f"Home Win: {home_win_prob}")
        print(f"Draw: {draw_prob}")
        print(f"Away Win: {away_win_prob}", end='\n\n')

        # Compare with the actual result from the dataset and output correct or false
        # ...

# %%
def rps(probs, outcome):
    cum_probs = np.cumsum(probs)
    cum_outcomes = np.cumsum(outcome)

    print(cum_outcomes)
    print(cum_probs)
    sum_rps = 0
    for i in range(len(outcome)):
        sum_rps+= (cum_probs[i] - cum_outcomes[i])**2

    return sum_rps/(len(outcome)-1)

# %%
# Main function
def main():
    # Load the results data file for seasons 2006-07 to 2016-17
    df_results = pd.read_csv('../data/results.csv')

    # Load the fixtures data file for the season 2017-18
    df_fixtures = pd.read_csv('../data/smallFixtures.csv')

    # Initialize ratings based on the results data
    ratings = initialize_ratings(df_results, df_fixtures)
    #print ('Ratings:', ratings, end='\n\n')

    """
    ratings['Leicester City']['brH'] = 0.463014
    ratings['Leicester City']['brA'] = 0.208624
    ratings['Leicester City']['continuous_overunderperformances'] = 3

    ratings['Stoke City']['brH'] = 0.537708
    ratings['Stoke City']['brA'] = 0.037819
    ratings['Stoke City']['continuous_overunderperformances'] = -1
    """


    # Calculate the rating difference between the two teams
    #predict_outcomes(df_fixtures, ratings)



    # Update ratings based on the results data
    ratings = update_ratings(df_results, ratings)

    # Call Ranked Probability Score function
    probs = [0.486, 0.261, 0.253]
    outcome = [1, 0, 0]
    rps_score = rps(probs, outcome)
    print("RPS Score:", rps_score, end='\n\n')

    for team, team_ratings in ratings.items():
        print(f"Team: {team}")
        print(f"Background Rating Home: {team_ratings['brH']}")
        print(f"Background Rating Away: {team_ratings['brA']}")
        print(f"Continuous Over/Underperformances: {team_ratings['continuous_overunderperformances']}")
        print()

    """
    # Calculate the mean and standard deviation of the rating differences
    rating_differences = calculate_rating_difference(df_results, ratings)
    mean = np.mean(rating_differences)
    std = np.std(rating_differences)
    print("Mean:", mean)
    print("Standard Deviation:", std, end='\n\n')
    """

# %%
if __name__ == '__main__':
    main()
# Out:
# Teams: {'Cardiff City', 'Bolton Wanderers', 'Blackpool', 'Queens Park Rangers', 'Leicester City', 'Sunderland', 'Crystal Palace', 'Portsmouth', 'Wolverhampton Wanderers', 'Derby County', 'AFC Bournemouth', 'Liverpool', 'Manchester United', 'Everton', 'Arsenal', 'Birmingham City', 'Hull City', 'Wigan Athletic', 'Norwich City', 'Reading', 'Swansea City', 'Watford', 'Newcastle United', 'Aston Villa', 'Chelsea', 'Stoke City', 'West Bromwich Albion', 'Blackburn Rovers', 'Tottenham Hotspur', 'Southampton', 'Manchester City', 'West Ham United', 'Burnley', 'Middlesbrough', 'Charlton Athletic', 'Fulham', 'Sheffield United'}
#
# Game Nr: 0
# Game Nr: 1
# Game Nr: 2
# Game Nr: 3
# Game Nr: 4
# Game Nr: 5
# Game Nr: 6
# Game Nr: 7
# Game Nr: 8
# Game Nr: 9
# Game Nr: 10
# Game Nr: 11
# Game Nr: 12
# Game Nr: 13
# Game Nr: 14
# Game Nr: 15
# Game Nr: 16
# Game Nr: 17
# Game Nr: 18
# Game Nr: 19
# Game Nr: 20
# Game Nr: 21
# Game Nr: 22
# Game Nr: 23
# Game Nr: 24
# Game Nr: 25
# Game Nr: 26
# Game Nr: 27
# Game Nr: 28
# Game Nr: 29
# Game Nr: 30
# Game Nr: 31
# Game Nr: 32
# Game Nr: 33
# Game Nr: 34
# Game Nr: 35
# Game Nr: 36
# Game Nr: 37
# Game Nr: 38
# Game Nr: 39
# Game Nr: 40
# Game Nr: 41
# Game Nr: 42
# Game Nr: 43
# Game Nr: 44
# Game Nr: 45
# Game Nr: 46
# Game Nr: 47
# Game Nr: 48
# Game Nr: 49
# Game Nr: 50
# Game Nr: 51
# Game Nr: 52
# Game Nr: 53
# Game Nr: 54
# Game Nr: 55
# Game Nr: 56
# Game Nr: 57
# Game Nr: 58
# Game Nr: 59
# Game Nr: 60
# Game Nr: 61
# Game Nr: 62
# Game Nr: 63
# Game Nr: 64
# Game Nr: 65
# Game Nr: 66
# Game Nr: 67
# Game Nr: 68
# Game Nr: 69
# Game Nr: 70
# Game Nr: 71
# Game Nr: 72
# Game Nr: 73
# Game Nr: 74
# Game Nr: 75
# Game Nr: 76
# Game Nr: 77
# Game Nr: 78
# Game Nr: 79
# Game Nr: 80
# Game Nr: 81
# Game Nr: 82
# Game Nr: 83
# Game Nr: 84
# Game Nr: 85
# Game Nr: 86
# Game Nr: 87
# Game Nr: 88
# Game Nr: 89
# Game Nr: 90
# Game Nr: 91
# Game Nr: 92
# Game Nr: 93
# Game Nr: 94
# Game Nr: 95
# Game Nr: 96
# Game Nr: 97
# Game Nr: 98
# Game Nr: 99
# Game Nr: 100
# Game Nr: 101
# Game Nr: 102
# Game Nr: 103
# Game Nr: 104
# Game Nr: 105
# Game Nr: 106
# Game Nr: 107
# Game Nr: 108
# Game Nr: 109
# Game Nr: 110
# Game Nr: 111
# Game Nr: 112
# Game Nr: 113
# Game Nr: 114
# Game Nr: 115
# Game Nr: 116
# Game Nr: 117
# Game Nr: 118
# Game Nr: 119
# Game Nr: 120
# Game Nr: 121
# Game Nr: 122
# Game Nr: 123
# Game Nr: 124
# Game Nr: 125
# Game Nr: 126
# Game Nr: 127
# Game Nr: 128
# Game Nr: 129
# Game Nr: 130
# Game Nr: 131
# Game Nr: 132
# Game Nr: 133
# Game Nr: 134
# Game Nr: 135
# Game Nr: 136
# Game Nr: 137
# Game Nr: 138
# Game Nr: 139
# Game Nr: 140
# Game Nr: 141
# Game Nr: 142
# Game Nr: 143
# Game Nr: 144
# Game Nr: 145
# Game Nr: 146
# Game Nr: 147
# Game Nr: 148
# Game Nr: 149
# Game Nr: 150
# Game Nr: 151
# Game Nr: 152
# Game Nr: 153
# Game Nr: 154
# Game Nr: 155
# Game Nr: 156
# Game Nr: 157
# Game Nr: 158
# Game Nr: 159
# Game Nr: 160
# Game Nr: 161
# Game Nr: 162
# Game Nr: 163
# Game Nr: 164
# Game Nr: 165
# Game Nr: 166
# Game Nr: 167
# Game Nr: 168
# Game Nr: 169
# Game Nr: 170
# Game Nr: 171
# Game Nr: 172
# Game Nr: 173
# Game Nr: 174
# Game Nr: 175
# Game Nr: 176
# Game Nr: 177
# Game Nr: 178
# Game Nr: 179
# Game Nr: 180
# Game Nr: 181
# Game Nr: 182
# Game Nr: 183
# Game Nr: 184
# Game Nr: 185
# Game Nr: 186
# Game Nr: 187
# Game Nr: 188
# Game Nr: 189
# Game Nr: 190
# Game Nr: 191
# Game Nr: 192
# Game Nr: 193
# Game Nr: 194
# Game Nr: 195
# Game Nr: 196
# Game Nr: 197
# Game Nr: 198
# Game Nr: 199
# Game Nr: 200
# Game Nr: 201
# Game Nr: 202
# Game Nr: 203
# Game Nr: 204
# Game Nr: 205
# Game Nr: 206
# Game Nr: 207
# Game Nr: 208
# Game Nr: 209
# Game Nr: 210
# Game Nr: 211
# Game Nr: 212
# Game Nr: 213
# Game Nr: 214
# Game Nr: 215
# Game Nr: 216
# Game Nr: 217
# Game Nr: 218
# Game Nr: 219
# Game Nr: 220
# Game Nr: 221
# Game Nr: 222
# Game Nr: 223
# Game Nr: 224
# Game Nr: 225
# Game Nr: 226
# Game Nr: 227
# Game Nr: 228
# Game Nr: 229
# Game Nr: 230
# Game Nr: 231
# Game Nr: 232
# Game Nr: 233
# Game Nr: 234
# Game Nr: 235
# Game Nr: 236
# Game Nr: 237
# Game Nr: 238
# Game Nr: 239
# Game Nr: 240
# Game Nr: 241
# Game Nr: 242
# Game Nr: 243
# Game Nr: 244
# Game Nr: 245
# Game Nr: 246
# Game Nr: 247
# Game Nr: 248
# Game Nr: 249
# Game Nr: 250
# Game Nr: 251
# Game Nr: 252
# Game Nr: 253
# Game Nr: 254
# Game Nr: 255
# Game Nr: 256
# Game Nr: 257
# Game Nr: 258
# Game Nr: 259
# Game Nr: 260
# Game Nr: 261
# Game Nr: 262
# Game Nr: 263
# Game Nr: 264
# Game Nr: 265
# Game Nr: 266
# Game Nr: 267
# Game Nr: 268
# Game Nr: 269
# Game Nr: 270
# Game Nr: 271
# Game Nr: 272
# Game Nr: 273
# Game Nr: 274
# Game Nr: 275
# Game Nr: 276
# Game Nr: 277
# Game Nr: 278
# Game Nr: 279
# Game Nr: 280
# Game Nr: 281
# Game Nr: 282
# Game Nr: 283
# Game Nr: 284
# Game Nr: 285
# Game Nr: 286
# Game Nr: 287
# Game Nr: 288
# Game Nr: 289
# Game Nr: 290
# Game Nr: 291
# Game Nr: 292
# Game Nr: 293
# Game Nr: 294
# Game Nr: 295
# Game Nr: 296
# Game Nr: 297
# Game Nr: 298
# Game Nr: 299
# Game Nr: 300
# Game Nr: 301
# Game Nr: 302
# Game Nr: 303
# Game Nr: 304
# Game Nr: 305
# Game Nr: 306
# Game Nr: 307
# Game Nr: 308
# Game Nr: 309
# Game Nr: 310
# Game Nr: 311
# Game Nr: 312
# Game Nr: 313
# Game Nr: 314
# Game Nr: 315
# Game Nr: 316
# Game Nr: 317
# Game Nr: 318
# Game Nr: 319
# Game Nr: 320
# Game Nr: 321
# Game Nr: 322
# Game Nr: 323
# Game Nr: 324
# Game Nr: 325
# Game Nr: 326
# Game Nr: 327
# Game Nr: 328
# Game Nr: 329
# Game Nr: 330
# Game Nr: 331
# Game Nr: 332
# Game Nr: 333
# Game Nr: 334
# Game Nr: 335
# Game Nr: 336
# Game Nr: 337
# Game Nr: 338
# Game Nr: 339
# Game Nr: 340
# Game Nr: 341
# Game Nr: 342
# Game Nr: 343
# Game Nr: 344
# Game Nr: 345
# Game Nr: 346
# Game Nr: 347
# Game Nr: 348
# Game Nr: 349
# Game Nr: 350
# Game Nr: 351
# Game Nr: 352
# Game Nr: 353
# Game Nr: 354
# Game Nr: 355
# Game Nr: 356
# Game Nr: 357
# Game Nr: 358
# Game Nr: 359
# Game Nr: 360
# Game Nr: 361
# Game Nr: 362
# Game Nr: 363
# Game Nr: 364
# Game Nr: 365
# Game Nr: 366
# Game Nr: 367
# Game Nr: 368
# Game Nr: 369
# Game Nr: 370
# Game Nr: 371
# Game Nr: 372
# Game Nr: 373
# Game Nr: 374
# Game Nr: 375
# Game Nr: 376
# Game Nr: 377
# Game Nr: 378
# Game Nr: 379
# Game Nr: 380
# Game Nr: 381
# Game Nr: 382
# Game Nr: 383
# Game Nr: 384
# Game Nr: 385
# Game Nr: 386
# Game Nr: 387
# Game Nr: 388
# Game Nr: 389
# Game Nr: 390
# Game Nr: 391
# Game Nr: 392
# Game Nr: 393
# Game Nr: 394
# Game Nr: 395
# Game Nr: 396
# Game Nr: 397
# Game Nr: 398
# Game Nr: 399
# Game Nr: 400
# Game Nr: 401
# Game Nr: 402
# Game Nr: 403
# Game Nr: 404
# Game Nr: 405
# Game Nr: 406
# Game Nr: 407
# Game Nr: 408
# Game Nr: 409
# Game Nr: 410
# Game Nr: 411
# Game Nr: 412
# Game Nr: 413
# Game Nr: 414
# Game Nr: 415
# Game Nr: 416
# Game Nr: 417
# Game Nr: 418
# Game Nr: 419
# Game Nr: 420
# Game Nr: 421
# Game Nr: 422
# Game Nr: 423
# Game Nr: 424
# Game Nr: 425
# Game Nr: 426
# Game Nr: 427
# Game Nr: 428
# Game Nr: 429
# Game Nr: 430
# Game Nr: 431
# Game Nr: 432
# Game Nr: 433
# Game Nr: 434
# Game Nr: 435
# Game Nr: 436
# Game Nr: 437
# Game Nr: 438
# Game Nr: 439
# Game Nr: 440
# Game Nr: 441
# Game Nr: 442
# Game Nr: 443
# Game Nr: 444
# Game Nr: 445
# Game Nr: 446
# Game Nr: 447
# Game Nr: 448
# Game Nr: 449
# Game Nr: 450
# Game Nr: 451
# Game Nr: 452
# Game Nr: 453
# Game Nr: 454
# Game Nr: 455
# Game Nr: 456
# Game Nr: 457
# Game Nr: 458
# Game Nr: 459
# Game Nr: 460
# Game Nr: 461
# Game Nr: 462
# Game Nr: 463
# Game Nr: 464
# Game Nr: 465
# Game Nr: 466
# Game Nr: 467
# Game Nr: 468
# Game Nr: 469
# Game Nr: 470
# Game Nr: 471
# Game Nr: 472
# Game Nr: 473
# Game Nr: 474
# Game Nr: 475
# Game Nr: 476
# Game Nr: 477
# Game Nr: 478
# Game Nr: 479
# Game Nr: 480
# Game Nr: 481
# Game Nr: 482
# Game Nr: 483
# Game Nr: 484
# Game Nr: 485
# Game Nr: 486
# Game Nr: 487
# Game Nr: 488
# Game Nr: 489
# Game Nr: 490
# Game Nr: 491
# Game Nr: 492
# Game Nr: 493
# Game Nr: 494
# Game Nr: 495
# Game Nr: 496
# Game Nr: 497
# Game Nr: 498
# Game Nr: 499
# Game Nr: 500
# Game Nr: 501
# Game Nr: 502
# Game Nr: 503
# Game Nr: 504
# Game Nr: 505
# Game Nr: 506
# Game Nr: 507
# Game Nr: 508
# Game Nr: 509
# Game Nr: 510
# Game Nr: 511
# Game Nr: 512
# Game Nr: 513
# Game Nr: 514
# Game Nr: 515
# Game Nr: 516
# Game Nr: 517
# Game Nr: 518
# Game Nr: 519
# Game Nr: 520
# Game Nr: 521
# Game Nr: 522
# Game Nr: 523
# Game Nr: 524
# Game Nr: 525
# Game Nr: 526
# Game Nr: 527
# Game Nr: 528
# Game Nr: 529
# Game Nr: 530
# Game Nr: 531
# Game Nr: 532
# Game Nr: 533
# Game Nr: 534
# Game Nr: 535
# Game Nr: 536
# Game Nr: 537
# Game Nr: 538
# Game Nr: 539
# Game Nr: 540
# Game Nr: 541
# Game Nr: 542
# Game Nr: 543
# Game Nr: 544
# Game Nr: 545
# Game Nr: 546
# Game Nr: 547
# Game Nr: 548
# Game Nr: 549
# Game Nr: 550
# Game Nr: 551
# Game Nr: 552
# Game Nr: 553
# Game Nr: 554
# Game Nr: 555
# Game Nr: 556
# Game Nr: 557
# Game Nr: 558
# Game Nr: 559
# Game Nr: 560
# Game Nr: 561
# Game Nr: 562
# Game Nr: 563
# Game Nr: 564
# Game Nr: 565
# Game Nr: 566
# Game Nr: 567
# Game Nr: 568
# Game Nr: 569
# Game Nr: 570
# Game Nr: 571
# Game Nr: 572
# Game Nr: 573
# Game Nr: 574
# Game Nr: 575
# Game Nr: 576
# Game Nr: 577
# Game Nr: 578
# Game Nr: 579
# Game Nr: 580
# Game Nr: 581
# Game Nr: 582
# Game Nr: 583
# Game Nr: 584
# Game Nr: 585
# Game Nr: 586
# Game Nr: 587
# Game Nr: 588
# Game Nr: 589
# Game Nr: 590
# Game Nr: 591
# Game Nr: 592
# Game Nr: 593
# Game Nr: 594
# Game Nr: 595
# Game Nr: 596
# Game Nr: 597
# Game Nr: 598
# Game Nr: 599
# Game Nr: 600
# Game Nr: 601
# Game Nr: 602
# Game Nr: 603
# Game Nr: 604
# Game Nr: 605
# Game Nr: 606
# Game Nr: 607
# Game Nr: 608
# Game Nr: 609
# Game Nr: 610
# Game Nr: 611
# Game Nr: 612
# Game Nr: 613
# Game Nr: 614
# Game Nr: 615
# Game Nr: 616
# Game Nr: 617
# Game Nr: 618
# Game Nr: 619
# Game Nr: 620
# Game Nr: 621
# Game Nr: 622
# Game Nr: 623
# Game Nr: 624
# Game Nr: 625
# Game Nr: 626
# Game Nr: 627
# Game Nr: 628
# Game Nr: 629
# Game Nr: 630
# Game Nr: 631
# Game Nr: 632
# Game Nr: 633
# Game Nr: 634
# Game Nr: 635
# Game Nr: 636
# Game Nr: 637
# Game Nr: 638
# Game Nr: 639
# Game Nr: 640
# Game Nr: 641
# Game Nr: 642
# Game Nr: 643
# Game Nr: 644
# Game Nr: 645
# Game Nr: 646
# Game Nr: 647
# Game Nr: 648
# Game Nr: 649
# Game Nr: 650
# Game Nr: 651
# Game Nr: 652
# Game Nr: 653
# Game Nr: 654
# Game Nr: 655
# Game Nr: 656
# Game Nr: 657
# Game Nr: 658
# Game Nr: 659
# Game Nr: 660
# Game Nr: 661
# Game Nr: 662
# Game Nr: 663
# Game Nr: 664
# Game Nr: 665
# Game Nr: 666
# Game Nr: 667
# Game Nr: 668
# Game Nr: 669
# Game Nr: 670
# Game Nr: 671
# Game Nr: 672
# Game Nr: 673
# Game Nr: 674
# Game Nr: 675
# Game Nr: 676
# Game Nr: 677
# Game Nr: 678
# Game Nr: 679
# Game Nr: 680
# Game Nr: 681
# Game Nr: 682
# Game Nr: 683
# Game Nr: 684
# Game Nr: 685
# Game Nr: 686
# Game Nr: 687
# Game Nr: 688
# Game Nr: 689
# Game Nr: 690
# Game Nr: 691
# Game Nr: 692
# Game Nr: 693
# Game Nr: 694
# Game Nr: 695
# Game Nr: 696
# Game Nr: 697
# Game Nr: 698
# Game Nr: 699
# Game Nr: 700
# Game Nr: 701
# Game Nr: 702
# Game Nr: 703
# Game Nr: 704
# Game Nr: 705
# Game Nr: 706
# Game Nr: 707
# Game Nr: 708
# Game Nr: 709
# Game Nr: 710
# Game Nr: 711
# Game Nr: 712
# Game Nr: 713
# Game Nr: 714
# Game Nr: 715
# Game Nr: 716
# Game Nr: 717
# Game Nr: 718
# Game Nr: 719
# Game Nr: 720
# Game Nr: 721
# Game Nr: 722
# Game Nr: 723
# Game Nr: 724
# Game Nr: 725
# Game Nr: 726
# Game Nr: 727
# Game Nr: 728
# Game Nr: 729
# Game Nr: 730
# Game Nr: 731
# Game Nr: 732
# Game Nr: 733
# Game Nr: 734
# Game Nr: 735
# Game Nr: 736
# Game Nr: 737
# Game Nr: 738
# Game Nr: 739
# Game Nr: 740
# Game Nr: 741
# Game Nr: 742
# Game Nr: 743
# Game Nr: 744
# Game Nr: 745
# Game Nr: 746
# Game Nr: 747
# Game Nr: 748
# Game Nr: 749
# Game Nr: 750
# Game Nr: 751
# Game Nr: 752
# Game Nr: 753
# Game Nr: 754
# Game Nr: 755
# Game Nr: 756
# Game Nr: 757
# Game Nr: 758
# Game Nr: 759
# Game Nr: 760
# Game Nr: 761
# Game Nr: 762
# Game Nr: 763
# Game Nr: 764
# Game Nr: 765
# Game Nr: 766
# Game Nr: 767
# Game Nr: 768
# Game Nr: 769
# Game Nr: 770
# Game Nr: 771
# Game Nr: 772
# Game Nr: 773
# Game Nr: 774
# Game Nr: 775
# Game Nr: 776
# Game Nr: 777
# Game Nr: 778
# Game Nr: 779
# Game Nr: 780
# Game Nr: 781
# Game Nr: 782
# Game Nr: 783
# Game Nr: 784
# Game Nr: 785
# Game Nr: 786
# Game Nr: 787
# Game Nr: 788
# Game Nr: 789
# Game Nr: 790
# Game Nr: 791
# Game Nr: 792
# Game Nr: 793
# Game Nr: 794
# Game Nr: 795
# Game Nr: 796
# Game Nr: 797
# Game Nr: 798
# Game Nr: 799
# Game Nr: 800
# Game Nr: 801
# Game Nr: 802
# Game Nr: 803
# Game Nr: 804
# Game Nr: 805
# Game Nr: 806
# Game Nr: 807
# Game Nr: 808
# Game Nr: 809
# Game Nr: 810
# Game Nr: 811
# Game Nr: 812
# Game Nr: 813
# Game Nr: 814
# Game Nr: 815
# Game Nr: 816
# Game Nr: 817
# Game Nr: 818
# Game Nr: 819
# Game Nr: 820
# Game Nr: 821
# Game Nr: 822
# Game Nr: 823
# Game Nr: 824
# Game Nr: 825
# Game Nr: 826
# Game Nr: 827
# Game Nr: 828
# Game Nr: 829
# Game Nr: 830
# Game Nr: 831
# Game Nr: 832
# Game Nr: 833
# Game Nr: 834
# Game Nr: 835
# Game Nr: 836
# Game Nr: 837
# Game Nr: 838
# Game Nr: 839
# Game Nr: 840
# Game Nr: 841
# Game Nr: 842
# Game Nr: 843
# Game Nr: 844
# Game Nr: 845
# Game Nr: 846
# Game Nr: 847
# Game Nr: 848
# Game Nr: 849
# Game Nr: 850
# Game Nr: 851
# Game Nr: 852
# Game Nr: 853
# Game Nr: 854
# Game Nr: 855
# Game Nr: 856
# Game Nr: 857
# Game Nr: 858
# Game Nr: 859
# Game Nr: 860
# Game Nr: 861
# Game Nr: 862
# Game Nr: 863
# Game Nr: 864
# Game Nr: 865
# Game Nr: 866
# Game Nr: 867
# Game Nr: 868
# Game Nr: 869
# Game Nr: 870
# Game Nr: 871
# Game Nr: 872
# Game Nr: 873
# Game Nr: 874
# Game Nr: 875
# Game Nr: 876
# Game Nr: 877
# Game Nr: 878
# Game Nr: 879
# Game Nr: 880
# Game Nr: 881
# Game Nr: 882
# Game Nr: 883
# Game Nr: 884
# Game Nr: 885
# Game Nr: 886
# Game Nr: 887
# Game Nr: 888
# Game Nr: 889
# Game Nr: 890
# Game Nr: 891
# Game Nr: 892
# Game Nr: 893
# Game Nr: 894
# Game Nr: 895
# Game Nr: 896
# Game Nr: 897
# Game Nr: 898
# Game Nr: 899
# Game Nr: 900
# Game Nr: 901
# Game Nr: 902
# Game Nr: 903
# Game Nr: 904
# Game Nr: 905
# Game Nr: 906
# Game Nr: 907
# Game Nr: 908
# Game Nr: 909
# Game Nr: 910
# Game Nr: 911
# Game Nr: 912
# Game Nr: 913
# Game Nr: 914
# Game Nr: 915
# Game Nr: 916
# Game Nr: 917
# Game Nr: 918
# Game Nr: 919
# Game Nr: 920
# Game Nr: 921
# Game Nr: 922
# Game Nr: 923
# Game Nr: 924
# Game Nr: 925
# Game Nr: 926
# Game Nr: 927
# Game Nr: 928
# Game Nr: 929
# Game Nr: 930
# Game Nr: 931
# Game Nr: 932
# Game Nr: 933
# Game Nr: 934
# Game Nr: 935
# Game Nr: 936
# Game Nr: 937
# Game Nr: 938
# Game Nr: 939
# Game Nr: 940
# Game Nr: 941
# Game Nr: 942
# Game Nr: 943
# Game Nr: 944
# Game Nr: 945
# Game Nr: 946
# Game Nr: 947
# Game Nr: 948
# Game Nr: 949
# Game Nr: 950
# Game Nr: 951
# Game Nr: 952
# Game Nr: 953
# Game Nr: 954
# Game Nr: 955
# Game Nr: 956
# Game Nr: 957
# Game Nr: 958
# Game Nr: 959
# Game Nr: 960
# Game Nr: 961
# Game Nr: 962
# Game Nr: 963
# Game Nr: 964
# Game Nr: 965
# Game Nr: 966
# Game Nr: 967
# Game Nr: 968
# Game Nr: 969
# Game Nr: 970
# Game Nr: 971
# Game Nr: 972
# Game Nr: 973
# Game Nr: 974
# Game Nr: 975
# Game Nr: 976
# Game Nr: 977
# Game Nr: 978
# Game Nr: 979
# Game Nr: 980
# Game Nr: 981
# Game Nr: 982
# Game Nr: 983
# Game Nr: 984
# Game Nr: 985
# Game Nr: 986
# Game Nr: 987
# Game Nr: 988
# Game Nr: 989
# Game Nr: 990
# Game Nr: 991
# Game Nr: 992
# Game Nr: 993
# Game Nr: 994
# Game Nr: 995
# Game Nr: 996
# Game Nr: 997
# Game Nr: 998
# Game Nr: 999
# Game Nr: 1000
# Game Nr: 1001
# Game Nr: 1002
# Game Nr: 1003
# Game Nr: 1004
# Game Nr: 1005
# Game Nr: 1006
# Game Nr: 1007
# Game Nr: 1008
# Game Nr: 1009
# Game Nr: 1010
# Game Nr: 1011
# Game Nr: 1012
# Game Nr: 1013
# Game Nr: 1014
# Game Nr: 1015
# Game Nr: 1016
# Game Nr: 1017
# Game Nr: 1018
# Game Nr: 1019
# Game Nr: 1020
# Game Nr: 1021
# Game Nr: 1022
# Game Nr: 1023
# Game Nr: 1024
# Game Nr: 1025
# Game Nr: 1026
# Game Nr: 1027
# Game Nr: 1028
# Game Nr: 1029
# Game Nr: 1030
# Game Nr: 1031
# Game Nr: 1032
# Game Nr: 1033
# Game Nr: 1034
# Game Nr: 1035
# Game Nr: 1036
# Game Nr: 1037
# Game Nr: 1038
# Game Nr: 1039
# Game Nr: 1040
# Game Nr: 1041
# Game Nr: 1042
# Game Nr: 1043
# Game Nr: 1044
# Game Nr: 1045
# Game Nr: 1046
# Game Nr: 1047
# Game Nr: 1048
# Game Nr: 1049
# Game Nr: 1050
# Game Nr: 1051
# Game Nr: 1052
# Game Nr: 1053
# Game Nr: 1054
# Game Nr: 1055
# Game Nr: 1056
# Game Nr: 1057
# Game Nr: 1058
# Game Nr: 1059
# Game Nr: 1060
# Game Nr: 1061
# Game Nr: 1062
# Game Nr: 1063
# Game Nr: 1064
# Game Nr: 1065
# Game Nr: 1066
# Game Nr: 1067
# Game Nr: 1068
# Game Nr: 1069
# Game Nr: 1070
# Game Nr: 1071
# Game Nr: 1072
# Game Nr: 1073
# Game Nr: 1074
# Game Nr: 1075
# Game Nr: 1076
# Game Nr: 1077
# Game Nr: 1078
# Game Nr: 1079
# Game Nr: 1080
# Game Nr: 1081
# Game Nr: 1082
# Game Nr: 1083
# Game Nr: 1084
# Game Nr: 1085
# Game Nr: 1086
# Game Nr: 1087
# Game Nr: 1088
# Game Nr: 1089
# Game Nr: 1090
# Game Nr: 1091
# Game Nr: 1092
# Game Nr: 1093
# Game Nr: 1094
# Game Nr: 1095
# Game Nr: 1096
# Game Nr: 1097
# Game Nr: 1098
# Game Nr: 1099
# Game Nr: 1100
# Game Nr: 1101
# Game Nr: 1102
# Game Nr: 1103
# Game Nr: 1104
# Game Nr: 1105
# Game Nr: 1106
# Game Nr: 1107
# Game Nr: 1108
# Game Nr: 1109
# Game Nr: 1110
# Game Nr: 1111
# Game Nr: 1112
# Game Nr: 1113
# Game Nr: 1114
# Game Nr: 1115
# Game Nr: 1116
# Game Nr: 1117
# Game Nr: 1118
# Game Nr: 1119
# Game Nr: 1120
# Game Nr: 1121
# Game Nr: 1122
# Game Nr: 1123
# Game Nr: 1124
# Game Nr: 1125
# Game Nr: 1126
# Game Nr: 1127
# Game Nr: 1128
# Game Nr: 1129
# Game Nr: 1130
# Game Nr: 1131
# Game Nr: 1132
# Game Nr: 1133
# Game Nr: 1134
# Game Nr: 1135
# Game Nr: 1136
# Game Nr: 1137
# Game Nr: 1138
# Game Nr: 1139
# Game Nr: 1140
# Game Nr: 1141
# Game Nr: 1142
# Game Nr: 1143
# Game Nr: 1144
# Game Nr: 1145
# Game Nr: 1146
# Game Nr: 1147
# Game Nr: 1148
# Game Nr: 1149
# Game Nr: 1150
# Game Nr: 1151
# Game Nr: 1152
# Game Nr: 1153
# Game Nr: 1154
# Game Nr: 1155
# Game Nr: 1156
# Game Nr: 1157
# Game Nr: 1158
# Game Nr: 1159
# Game Nr: 1160
# Game Nr: 1161
# Game Nr: 1162
# Game Nr: 1163
# Game Nr: 1164
# Game Nr: 1165
# Game Nr: 1166
# Game Nr: 1167
# Game Nr: 1168
# Game Nr: 1169
# Game Nr: 1170
# Game Nr: 1171
# Game Nr: 1172
# Game Nr: 1173
# Game Nr: 1174
# Game Nr: 1175
# Game Nr: 1176
# Game Nr: 1177
# Game Nr: 1178
# Game Nr: 1179
# Game Nr: 1180
# Game Nr: 1181
# Game Nr: 1182
# Game Nr: 1183
# Game Nr: 1184
# Game Nr: 1185
# Game Nr: 1186
# Game Nr: 1187
# Game Nr: 1188
# Game Nr: 1189
# Game Nr: 1190
# Game Nr: 1191
# Game Nr: 1192
# Game Nr: 1193
# Game Nr: 1194
# Game Nr: 1195
# Game Nr: 1196
# Game Nr: 1197
# Game Nr: 1198
# Game Nr: 1199
# Game Nr: 1200
# Game Nr: 1201
# Game Nr: 1202
# Game Nr: 1203
# Game Nr: 1204
# Game Nr: 1205
# Game Nr: 1206
# Game Nr: 1207
# Game Nr: 1208
# Game Nr: 1209
# Game Nr: 1210
# Game Nr: 1211
# Game Nr: 1212
# Game Nr: 1213
# Game Nr: 1214
# Game Nr: 1215
# Game Nr: 1216
# Game Nr: 1217
# Game Nr: 1218
# Game Nr: 1219
# Game Nr: 1220
# Game Nr: 1221
# Game Nr: 1222
# Game Nr: 1223
# Game Nr: 1224
# Game Nr: 1225
# Game Nr: 1226
# Game Nr: 1227
# Game Nr: 1228
# Game Nr: 1229
# Game Nr: 1230
# Game Nr: 1231
# Game Nr: 1232
# Game Nr: 1233
# Game Nr: 1234
# Game Nr: 1235
# Game Nr: 1236
# Game Nr: 1237
# Game Nr: 1238
# Game Nr: 1239
# Game Nr: 1240
# Game Nr: 1241
# Game Nr: 1242
# Game Nr: 1243
# Game Nr: 1244
# Game Nr: 1245
# Game Nr: 1246
# Game Nr: 1247
# Game Nr: 1248
# Game Nr: 1249
# Game Nr: 1250
# Game Nr: 1251
# Game Nr: 1252
# Game Nr: 1253
# Game Nr: 1254
# Game Nr: 1255
# Game Nr: 1256
# Game Nr: 1257
# Game Nr: 1258
# Game Nr: 1259
# Game Nr: 1260
# Game Nr: 1261
# Game Nr: 1262
# Game Nr: 1263
# Game Nr: 1264
# Game Nr: 1265
# Game Nr: 1266
# Game Nr: 1267
# Game Nr: 1268
# Game Nr: 1269
# Game Nr: 1270
# Game Nr: 1271
# Game Nr: 1272
# Game Nr: 1273
# Game Nr: 1274
# Game Nr: 1275
# Game Nr: 1276
# Game Nr: 1277
# Game Nr: 1278
# Game Nr: 1279
# Game Nr: 1280
# Game Nr: 1281
# Game Nr: 1282
# Game Nr: 1283
# Game Nr: 1284
# Game Nr: 1285
# Game Nr: 1286
# Game Nr: 1287
# Game Nr: 1288
# Game Nr: 1289
# Game Nr: 1290
# Game Nr: 1291
# Game Nr: 1292
# Game Nr: 1293
# Game Nr: 1294
# Game Nr: 1295
# Game Nr: 1296
# Game Nr: 1297
# Game Nr: 1298
# Game Nr: 1299
# Game Nr: 1300
# Game Nr: 1301
# Game Nr: 1302
# Game Nr: 1303
# Game Nr: 1304
# Game Nr: 1305
# Game Nr: 1306
# Game Nr: 1307
# Game Nr: 1308
# Game Nr: 1309
# Game Nr: 1310
# Game Nr: 1311
# Game Nr: 1312
# Game Nr: 1313
# Game Nr: 1314
# Game Nr: 1315
# Game Nr: 1316
# Game Nr: 1317
# Game Nr: 1318
# Game Nr: 1319
# Game Nr: 1320
# Game Nr: 1321
# Game Nr: 1322
# Game Nr: 1323
# Game Nr: 1324
# Game Nr: 1325
# Game Nr: 1326
# Game Nr: 1327
# Game Nr: 1328
# Game Nr: 1329
# Game Nr: 1330
# Game Nr: 1331
# Game Nr: 1332
# Game Nr: 1333
# Game Nr: 1334
# Game Nr: 1335
# Game Nr: 1336
# Game Nr: 1337
# Game Nr: 1338
# Game Nr: 1339
# Game Nr: 1340
# Game Nr: 1341
# Game Nr: 1342
# Game Nr: 1343
# Game Nr: 1344
# Game Nr: 1345
# Game Nr: 1346
# Game Nr: 1347
# Game Nr: 1348
# Game Nr: 1349
# Game Nr: 1350
# Game Nr: 1351
# Game Nr: 1352
# Game Nr: 1353
# Game Nr: 1354
# Game Nr: 1355
# Game Nr: 1356
# Game Nr: 1357
# Game Nr: 1358
# Game Nr: 1359
# Game Nr: 1360
# Game Nr: 1361
# Game Nr: 1362
# Game Nr: 1363
# Game Nr: 1364
# Game Nr: 1365
# Game Nr: 1366
# Game Nr: 1367
# Game Nr: 1368
# Game Nr: 1369
# Game Nr: 1370
# Game Nr: 1371
# Game Nr: 1372
# Game Nr: 1373
# Game Nr: 1374
# Game Nr: 1375
# Game Nr: 1376
# Game Nr: 1377
# Game Nr: 1378
# Game Nr: 1379
# Game Nr: 1380
# Game Nr: 1381
# Game Nr: 1382
# Game Nr: 1383
# Game Nr: 1384
# Game Nr: 1385
# Game Nr: 1386
# Game Nr: 1387
# Game Nr: 1388
# Game Nr: 1389
# Game Nr: 1390
# Game Nr: 1391
# Game Nr: 1392
# Game Nr: 1393
# Game Nr: 1394
# Game Nr: 1395
# Game Nr: 1396
# Game Nr: 1397
# Game Nr: 1398
# Game Nr: 1399
# Game Nr: 1400
# Game Nr: 1401
# Game Nr: 1402
# Game Nr: 1403
# Game Nr: 1404
# Game Nr: 1405
# Game Nr: 1406
# Game Nr: 1407
# Game Nr: 1408
# Game Nr: 1409
# Game Nr: 1410
# Game Nr: 1411
# Game Nr: 1412
# Game Nr: 1413
# Game Nr: 1414
# Game Nr: 1415
# Game Nr: 1416
# Game Nr: 1417
# Game Nr: 1418
# Game Nr: 1419
# Game Nr: 1420
# Game Nr: 1421
# Game Nr: 1422
# Game Nr: 1423
# Game Nr: 1424
# Game Nr: 1425
# Game Nr: 1426
# Game Nr: 1427
# Game Nr: 1428
# Game Nr: 1429
# Game Nr: 1430
# Game Nr: 1431
# Game Nr: 1432
# Game Nr: 1433
# Game Nr: 1434
# Game Nr: 1435
# Game Nr: 1436
# Game Nr: 1437
# Game Nr: 1438
# Game Nr: 1439
# Game Nr: 1440
# Game Nr: 1441
# Game Nr: 1442
# Game Nr: 1443
# Game Nr: 1444
# Game Nr: 1445
# Game Nr: 1446
# Game Nr: 1447
# Game Nr: 1448
# Game Nr: 1449
# Game Nr: 1450
# Game Nr: 1451
# Game Nr: 1452
# Game Nr: 1453
# Game Nr: 1454
# Game Nr: 1455
# Game Nr: 1456
# Game Nr: 1457
# Game Nr: 1458
# Game Nr: 1459
# Game Nr: 1460
# Game Nr: 1461
# Game Nr: 1462
# Game Nr: 1463
# Game Nr: 1464
# Game Nr: 1465
# Game Nr: 1466
# Game Nr: 1467
# Game Nr: 1468
# Game Nr: 1469
# Game Nr: 1470
# Game Nr: 1471
# Game Nr: 1472
# Game Nr: 1473
# Game Nr: 1474
# Game Nr: 1475
# Game Nr: 1476
# Game Nr: 1477
# Game Nr: 1478
# Game Nr: 1479
# Game Nr: 1480
# Game Nr: 1481
# Game Nr: 1482
# Game Nr: 1483
# Game Nr: 1484
# Game Nr: 1485
# Game Nr: 1486
# Game Nr: 1487
# Game Nr: 1488
# Game Nr: 1489
# Game Nr: 1490
# Game Nr: 1491
# Game Nr: 1492
# Game Nr: 1493
# Game Nr: 1494
# Game Nr: 1495
# Game Nr: 1496
# Game Nr: 1497
# Game Nr: 1498
# Game Nr: 1499
# Game Nr: 1500
# Game Nr: 1501
# Game Nr: 1502
# Game Nr: 1503
# Game Nr: 1504
# Game Nr: 1505
# Game Nr: 1506
# Game Nr: 1507
# Game Nr: 1508
# Game Nr: 1509
# Game Nr: 1510
# Game Nr: 1511
# Game Nr: 1512
# Game Nr: 1513
# Game Nr: 1514
# Game Nr: 1515
# Game Nr: 1516
# Game Nr: 1517
# Game Nr: 1518
# Game Nr: 1519
# Game Nr: 1520
# Game Nr: 1521
# Game Nr: 1522
# Game Nr: 1523
# Game Nr: 1524
# Game Nr: 1525
# Game Nr: 1526
# Game Nr: 1527
# Game Nr: 1528
# Game Nr: 1529
# Game Nr: 1530
# Game Nr: 1531
# Game Nr: 1532
# Game Nr: 1533
# Game Nr: 1534
# Game Nr: 1535
# Game Nr: 1536
# Game Nr: 1537
# Game Nr: 1538
# Game Nr: 1539
# Game Nr: 1540
# Game Nr: 1541
# Game Nr: 1542
# Game Nr: 1543
# Game Nr: 1544
# Game Nr: 1545
# Game Nr: 1546
# Game Nr: 1547
# Game Nr: 1548
# Game Nr: 1549
# Game Nr: 1550
# Game Nr: 1551
# Game Nr: 1552
# Game Nr: 1553
# Game Nr: 1554
# Game Nr: 1555
# Game Nr: 1556
# Game Nr: 1557
# Game Nr: 1558
# Game Nr: 1559
# Game Nr: 1560
# Game Nr: 1561
# Game Nr: 1562
# Game Nr: 1563
# Game Nr: 1564
# Game Nr: 1565
# Game Nr: 1566
# Game Nr: 1567
# Game Nr: 1568
# Game Nr: 1569
# Game Nr: 1570
# Game Nr: 1571
# Game Nr: 1572
# Game Nr: 1573
# Game Nr: 1574
# Game Nr: 1575
# Game Nr: 1576
# Game Nr: 1577
# Game Nr: 1578
# Game Nr: 1579
# Game Nr: 1580
# Game Nr: 1581
# Game Nr: 1582
# Game Nr: 1583
# Game Nr: 1584
# Game Nr: 1585
# Game Nr: 1586
# Game Nr: 1587
# Game Nr: 1588
# Game Nr: 1589
# Game Nr: 1590
# Game Nr: 1591
# Game Nr: 1592
# Game Nr: 1593
# Game Nr: 1594
# Game Nr: 1595
# Game Nr: 1596
# Game Nr: 1597
# Game Nr: 1598
# Game Nr: 1599
# Game Nr: 1600
# Game Nr: 1601
# Game Nr: 1602
# Game Nr: 1603
# Game Nr: 1604
# Game Nr: 1605
# Game Nr: 1606
# Game Nr: 1607
# Game Nr: 1608
# Game Nr: 1609
# Game Nr: 1610
# Game Nr: 1611
# Game Nr: 1612
# Game Nr: 1613
# Game Nr: 1614
# Game Nr: 1615
# Game Nr: 1616
# Game Nr: 1617
# Game Nr: 1618
# Game Nr: 1619
# Game Nr: 1620
# Game Nr: 1621
# Game Nr: 1622
# Game Nr: 1623
# Game Nr: 1624
# Game Nr: 1625
# Game Nr: 1626
# Game Nr: 1627
# Game Nr: 1628
# Game Nr: 1629
# Game Nr: 1630
# Game Nr: 1631
# Game Nr: 1632
# Game Nr: 1633
# Game Nr: 1634
# Game Nr: 1635
# Game Nr: 1636
# Game Nr: 1637
# Game Nr: 1638
# Game Nr: 1639
# Game Nr: 1640
# Game Nr: 1641
# Game Nr: 1642
# Game Nr: 1643
# Game Nr: 1644
# Game Nr: 1645
# Game Nr: 1646
# Game Nr: 1647
# Game Nr: 1648
# Game Nr: 1649
# Game Nr: 1650
# Game Nr: 1651
# Game Nr: 1652
# Game Nr: 1653
# Game Nr: 1654
# Game Nr: 1655
# Game Nr: 1656
# Game Nr: 1657
# Game Nr: 1658
# Game Nr: 1659
# Game Nr: 1660
# Game Nr: 1661
# Game Nr: 1662
# Game Nr: 1663
# Game Nr: 1664
# Game Nr: 1665
# Game Nr: 1666
# Game Nr: 1667
# Game Nr: 1668
# Game Nr: 1669
# Game Nr: 1670
# Game Nr: 1671
# Game Nr: 1672
# Game Nr: 1673
# Game Nr: 1674
# Game Nr: 1675
# Game Nr: 1676
# Game Nr: 1677
# Game Nr: 1678
# Game Nr: 1679
# Game Nr: 1680
# Game Nr: 1681
# Game Nr: 1682
# Game Nr: 1683
# Game Nr: 1684
# Game Nr: 1685
# Game Nr: 1686
# Game Nr: 1687
# Game Nr: 1688
# Game Nr: 1689
# Game Nr: 1690
# Game Nr: 1691
# Game Nr: 1692
# Game Nr: 1693
# Game Nr: 1694
# Game Nr: 1695
# Game Nr: 1696
# Game Nr: 1697
# Game Nr: 1698
# Game Nr: 1699
# Game Nr: 1700
# Game Nr: 1701
# Game Nr: 1702
# Game Nr: 1703
# Game Nr: 1704
# Game Nr: 1705
# Game Nr: 1706
# Game Nr: 1707
# Game Nr: 1708
# Game Nr: 1709
# Game Nr: 1710
# Game Nr: 1711
# Game Nr: 1712
# Game Nr: 1713
# Game Nr: 1714
# Game Nr: 1715
# Game Nr: 1716
# Game Nr: 1717
# Game Nr: 1718
# Game Nr: 1719
# Game Nr: 1720
# Game Nr: 1721
# Game Nr: 1722
# Game Nr: 1723
# Game Nr: 1724
# Game Nr: 1725
# Game Nr: 1726
# Game Nr: 1727
# Game Nr: 1728
# Game Nr: 1729
# Game Nr: 1730
# Game Nr: 1731
# Game Nr: 1732
# Game Nr: 1733
# Game Nr: 1734
# Game Nr: 1735
# Game Nr: 1736
# Game Nr: 1737
# Game Nr: 1738
# Game Nr: 1739
# Game Nr: 1740
# Game Nr: 1741
# Game Nr: 1742
# Game Nr: 1743
# Game Nr: 1744
# Game Nr: 1745
# Game Nr: 1746
# Game Nr: 1747
# Game Nr: 1748
# Game Nr: 1749
# Game Nr: 1750
# Game Nr: 1751
# Game Nr: 1752
# Game Nr: 1753
# Game Nr: 1754
# Game Nr: 1755
# Game Nr: 1756
# Game Nr: 1757
# Game Nr: 1758
# Game Nr: 1759
# Game Nr: 1760
# Game Nr: 1761
# Game Nr: 1762
# Game Nr: 1763
# Game Nr: 1764
# Game Nr: 1765
# Game Nr: 1766
# Game Nr: 1767
# Game Nr: 1768
# Game Nr: 1769
# Game Nr: 1770
# Game Nr: 1771
# Game Nr: 1772
# Game Nr: 1773
# Game Nr: 1774
# Game Nr: 1775
# Game Nr: 1776
# Game Nr: 1777
# Game Nr: 1778
# Game Nr: 1779
# Game Nr: 1780
# Game Nr: 1781
# Game Nr: 1782
# Game Nr: 1783
# Game Nr: 1784
# Game Nr: 1785
# Game Nr: 1786
# Game Nr: 1787
# Game Nr: 1788
# Game Nr: 1789
# Game Nr: 1790
# Game Nr: 1791
# Game Nr: 1792
# Game Nr: 1793
# Game Nr: 1794
# Game Nr: 1795
# Game Nr: 1796
# Game Nr: 1797
# Game Nr: 1798
# Game Nr: 1799
# Game Nr: 1800
# Game Nr: 1801
# Game Nr: 1802
# Game Nr: 1803
# Game Nr: 1804
# Game Nr: 1805
# Game Nr: 1806
# Game Nr: 1807
# Game Nr: 1808
# Game Nr: 1809
# Game Nr: 1810
# Game Nr: 1811
# Game Nr: 1812
# Game Nr: 1813
# Game Nr: 1814
# Game Nr: 1815
# Game Nr: 1816
# Game Nr: 1817
# Game Nr: 1818
# Game Nr: 1819
# Game Nr: 1820
# Game Nr: 1821
# Game Nr: 1822
# Game Nr: 1823
# Game Nr: 1824
# Game Nr: 1825
# Game Nr: 1826
# Game Nr: 1827
# Game Nr: 1828
# Game Nr: 1829
# Game Nr: 1830
# Game Nr: 1831
# Game Nr: 1832
# Game Nr: 1833
# Game Nr: 1834
# Game Nr: 1835
# Game Nr: 1836
# Game Nr: 1837
# Game Nr: 1838
# Game Nr: 1839
# Game Nr: 1840
# Game Nr: 1841
# Game Nr: 1842
# Game Nr: 1843
# Game Nr: 1844
# Game Nr: 1845
# Game Nr: 1846
# Game Nr: 1847
# Game Nr: 1848
# Game Nr: 1849
# Game Nr: 1850
# Game Nr: 1851
# Game Nr: 1852
# Game Nr: 1853
# Game Nr: 1854
# Game Nr: 1855
# Game Nr: 1856
# Game Nr: 1857
# Game Nr: 1858
# Game Nr: 1859
# Game Nr: 1860
# Game Nr: 1861
# Game Nr: 1862
# Game Nr: 1863
# Game Nr: 1864
# Game Nr: 1865
# Game Nr: 1866
# Game Nr: 1867
# Game Nr: 1868
# Game Nr: 1869
# Game Nr: 1870
# Game Nr: 1871
# Game Nr: 1872
# Game Nr: 1873
# Game Nr: 1874
# Game Nr: 1875
# Game Nr: 1876
# Game Nr: 1877
# Game Nr: 1878
# Game Nr: 1879
# Game Nr: 1880
# Game Nr: 1881
# Game Nr: 1882
# Game Nr: 1883
# Game Nr: 1884
# Game Nr: 1885
# Game Nr: 1886
# Game Nr: 1887
# Game Nr: 1888
# Game Nr: 1889
# Game Nr: 1890
# Game Nr: 1891
# Game Nr: 1892
# Game Nr: 1893
# Game Nr: 1894
# Game Nr: 1895
# Game Nr: 1896
# Game Nr: 1897
# Game Nr: 1898
# Game Nr: 1899
# Game Nr: 1900
# Game Nr: 1901
# Game Nr: 1902
# Game Nr: 1903
# Game Nr: 1904
# Game Nr: 1905
# Game Nr: 1906
# Game Nr: 1907
# Game Nr: 1908
# Game Nr: 1909
# Game Nr: 1910
# Game Nr: 1911
# Game Nr: 1912
# Game Nr: 1913
# Game Nr: 1914
# Game Nr: 1915
# Game Nr: 1916
# Game Nr: 1917
# Game Nr: 1918
# Game Nr: 1919
# Game Nr: 1920
# Game Nr: 1921
# Game Nr: 1922
# Game Nr: 1923
# Game Nr: 1924
# Game Nr: 1925
# Game Nr: 1926
# Game Nr: 1927
# Game Nr: 1928
# Game Nr: 1929
# Game Nr: 1930
# Game Nr: 1931
# Game Nr: 1932
# Game Nr: 1933
# Game Nr: 1934
# Game Nr: 1935
# Game Nr: 1936
# Game Nr: 1937
# Game Nr: 1938
# Game Nr: 1939
# Game Nr: 1940
# Game Nr: 1941
# Game Nr: 1942
# Game Nr: 1943
# Game Nr: 1944
# Game Nr: 1945
# Game Nr: 1946
# Game Nr: 1947
# Game Nr: 1948
# Game Nr: 1949
# Game Nr: 1950
# Game Nr: 1951
# Game Nr: 1952
# Game Nr: 1953
# Game Nr: 1954
# Game Nr: 1955
# Game Nr: 1956
# Game Nr: 1957
# Game Nr: 1958
# Game Nr: 1959
# Game Nr: 1960
# Game Nr: 1961
# Game Nr: 1962
# Game Nr: 1963
# Game Nr: 1964
# Game Nr: 1965
# Game Nr: 1966
# Game Nr: 1967
# Game Nr: 1968
# Game Nr: 1969
# Game Nr: 1970
# Game Nr: 1971
# Game Nr: 1972
# Game Nr: 1973
# Game Nr: 1974
# Game Nr: 1975
# Game Nr: 1976
# Game Nr: 1977
# Game Nr: 1978
# Game Nr: 1979
# Game Nr: 1980
# Game Nr: 1981
# Game Nr: 1982
# Game Nr: 1983
# Game Nr: 1984
# Game Nr: 1985
# Game Nr: 1986
# Game Nr: 1987
# Game Nr: 1988
# Game Nr: 1989
# Game Nr: 1990
# Game Nr: 1991
# Game Nr: 1992
# Game Nr: 1993
# Game Nr: 1994
# Game Nr: 1995
# Game Nr: 1996
# Game Nr: 1997
# Game Nr: 1998
# Game Nr: 1999
# Game Nr: 2000
# [1 1 1]
# [0.486 0.747 1.   ]
# RPS Score: 0.16410249999999998
#
# Team: Cardiff City
# Background Rating Home: 0.0
# Background Rating Away: 0.0
# Continuous Over/Underperformances: 0
#
# Team: Bolton Wanderers
# Background Rating Home: 26.497963744819366
# Background Rating Away: 24.1861388451023
# Continuous Over/Underperformances: -1
#
# Team: Blackpool
# Background Rating Home: 24.928091650058207
# Background Rating Away: 25.1099625206982
# Continuous Over/Underperformances: 5
#
# Team: Queens Park Rangers
# Background Rating Home: 14.805973882029345
# Background Rating Away: 15.22211959877977
# Continuous Over/Underperformances: 9
#
# Team: Leicester City
# Background Rating Home: 0.0
# Background Rating Away: 0.0
# Continuous Over/Underperformances: 0
#
# Team: Sunderland
# Background Rating Home: 24.418361456207368
# Background Rating Away: 27.169639739451533
# Continuous Over/Underperformances: 1
#
# Team: Crystal Palace
# Background Rating Home: 0.0
# Background Rating Away: 0.0
# Continuous Over/Underperformances: 0
#
# Team: Portsmouth
# Background Rating Home: 5.4474579856492396
# Background Rating Away: 5.206552574515369
# Continuous Over/Underperformances: 4
#
# Team: Wolverhampton Wanderers
# Background Rating Home: 24.461438316723303
# Background Rating Away: 26.4172064290448
# Continuous Over/Underperformances: -2
#
# Team: Derby County
# Background Rating Home: -2.501869424090243
# Background Rating Away: -2.555308454166648
# Continuous Over/Underperformances: -30
#
# Team: AFC Bournemouth
# Background Rating Home: 0.0
# Background Rating Away: 0.0
# Continuous Over/Underperformances: 0
#
# Team: Liverpool
# Background Rating Home: 26.617178981407243
# Background Rating Away: 28.827588121568652
# Continuous Over/Underperformances: 1
#
# Team: Manchester United
# Background Rating Home: 27.048177061900503
# Background Rating Away: 28.420428140473472
# Continuous Over/Underperformances: 3
#
# Team: Everton
# Background Rating Home: 30.21637907243215
# Background Rating Away: 30.75102253932742
# Continuous Over/Underperformances: 1
#
# Team: Arsenal
# Background Rating Home: 25.67488198285792
# Background Rating Away: 25.728021140084014
# Continuous Over/Underperformances: -1
#
# Team: Birmingham City
# Background Rating Home: 22.982933260997466
# Background Rating Away: 24.406910982813212
# Continuous Over/Underperformances: 5
#
# Team: Hull City
# Background Rating Home: 5.368552983189698
# Background Rating Away: 5.588947533044663
# Continuous Over/Underperformances: 2
#
# Team: Wigan Athletic
# Background Rating Home: 0.0
# Background Rating Away: 0.0
# Continuous Over/Underperformances: 0
#
# Team: Norwich City
# Background Rating Home: 11.031109348769816
# Background Rating Away: 10.865332719908745
# Continuous Over/Underperformances: 9
#
# Team: Reading
# Background Rating Home: 0.2073857090812645
# Background Rating Away: 0.04199828523688065
# Continuous Over/Underperformances: 1
#
# Team: Swansea City
# Background Rating Home: 10.639430957657467
# Background Rating Away: 10.517740216226034
# Continuous Over/Underperformances: 2
#
# Team: Watford
# Background Rating Home: -1.3096490402761107
# Background Rating Away: -1.4398831725270371
# Continuous Over/Underperformances: -1
#
# Team: Newcastle United
# Background Rating Home: 28.40747291111736
# Background Rating Away: 25.999021552793607
# Continuous Over/Underperformances: -1
#
# Team: Aston Villa
# Background Rating Home: 25.65830950868722
# Background Rating Away: 28.221989240897642
# Continuous Over/Underperformances: -1
#
# Team: Chelsea
# Background Rating Home: 27.027709085960254
# Background Rating Away: 24.896166831337293
# Continuous Over/Underperformances: 1
#
# Team: Stoke City
# Background Rating Home: 27.565138202914074
# Background Rating Away: 29.339355193944346
# Continuous Over/Underperformances: -2
#
# Team: West Bromwich Albion
# Background Rating Home: 26.319696501830677
# Background Rating Away: 23.67017981585368
# Continuous Over/Underperformances: -3
#
# Team: Blackburn Rovers
# Background Rating Home: 24.97451844095912
# Background Rating Away: 28.532857141367234
# Continuous Over/Underperformances: -3
#
# Team: Tottenham Hotspur
# Background Rating Home: 25.31704898504403
# Background Rating Away: 26.738172592129096
# Continuous Over/Underperformances: -1
#
# Team: Southampton
# Background Rating Home: 0.0
# Background Rating Away: 0.0
# Continuous Over/Underperformances: 0
#
# Team: Manchester City
# Background Rating Home: 26.809265787299193
# Background Rating Away: 25.338860007927607
# Continuous Over/Underperformances: 1
#
# Team: West Ham United
# Background Rating Home: -388.2646417318867
# Background Rating Away: -386.5087549856928
# Continuous Over/Underperformances: -111
#
# Team: Burnley
# Background Rating Home: 4.769060175643614
# Background Rating Away: 4.7035338696730875
# Continuous Over/Underperformances: -1
#
# Team: Middlesbrough
# Background Rating Home: 1.3901345672196954
# Background Rating Away: 1.0822355002975117
# Continuous Over/Underperformances: 2
#
# Team: Charlton Athletic
# Background Rating Home: -1.2018860060751537
# Background Rating Away: -1.373122975365107
# Continuous Over/Underperformances: -7
#
# Team: Fulham
# Background Rating Home: -108.82615337839128
# Background Rating Away: -109.92790297181402
# Continuous Over/Underperformances: -28
#
# Team: Sheffield United
# Background Rating Home: -0.709231511642604
# Background Rating Away: -0.9472480410240192
# Continuous Over/Underperformances: -1
